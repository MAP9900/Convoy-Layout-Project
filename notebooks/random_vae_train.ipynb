# %% [markdown]
# # Random Baseline VAE Train Notebook
#
# Main notebook for training the attack-profile VAE on profile-first random baseline data.
#
# Default workflow:
# 1. Generate a random-profile `45k / 5k` train-valid split.
# 2. Sanity-check the JSONL datasets and random acceptance rates.
# 3. Train the VAE with the same hyperparameters as the curated v4 notebook.
# 4. Sample decoded profiles and compare their spawn distribution against the random training data.

# %% [markdown]
# ## Imports

# %%
from __future__ import annotations

import csv
import json
import random
import sys
import time
from collections import Counter
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
from torch.optim import Adam
from torch.utils.data import DataLoader

# Resolve repo root when this notebook is launched from either repo root or notebooks/.
PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / "convoy_sim").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from convoy_sim.attack_profiles import AttackProfile
from convoy_sim.profile_audit import AuditThresholds, audit_attack_profiles
from convoy_sim.profile_generation_viz import (
    FIXED_X_LIMITS,
    apply_limits,
    combined_limits,
    plot_spawn_comparison,
    simple_ship_polygons,
    style_ax,
)
from convoy_sim.profile_outcome_audit import OutcomeAuditConfig
from convoy_sim.vae import (
    AttackProfileVAE,
    AttackProfileVAEPreprocessor,
    build_latent_bank,
    build_vae_datasets,
    load_attack_profile_dataset_jsonl,
    vae_loss,
)
from convoy_sim.vae_diagnostics import audit_decoded_vae_payloads, summarize_decoded_vae_audit
from convoy_sim.workflows import ensure_dir, git_sha, resolve_run_dir, write_json, write_yaml
from experiments.audit_attack_profile_dataset import flatten_dataset_records, load_dataset_records, summarize_flat_rows
from experiments.generate_attack_profile_scaffold import MIN_SPAWN_CLEARANCE_M
from experiments.generate_random_attack_profile_dataset import RANDOM_BASELINE_MODE, generate_random_baseline_records
from scenarios.convoy_profiles import get_convoy_layout_profile

PROJECT_ROOT
# Out:
# PosixPath('/Users/matthewplambeck/Desktop/Convoy Layout Project')

# %% [markdown]
# ## Config

# %%
# Dataset generation.
GENERATE_DATASETS = True
FORCE_REGENERATE_DATASETS = True
TRAIN_COUNT = 45_000
VALID_COUNT = 5_000
GENERATION_CHUNK_SIZE = 1_000
CONVOY_PROFILE = "convoy_layout_1"
GENERATION_MODE = RANDOM_BASELINE_MODE
TRAIN_SEED = 1945
VALID_SEED = 2945

TRAIN_PATH = Path("data/attack_profiles/synthetic/train_random_profile_v1_45k.jsonl")
VALID_PATH = Path("data/attack_profiles/synthetic/valid_random_profile_v1_5k.jsonl")

# Training.
RUN_TRAINING = True
EXISTING_RUN_DIR = Path("results/runs/vae") / "SET_ME_IF_RUN_TRAINING_FALSE"
OUTPUT_ROOT = Path("results/runs")
RUN_NAME = "random_v1_notebook"
DEVICE = "auto"  # auto, cpu, cuda, or mps
SEED = 1945
EPOCHS = 60
BATCH_SIZE = 512
LEARNING_RATE = 1e-3
BETA = 0.03
LATENT_DIM = 6
HIDDEN_DIM = 64
NUM_WORKERS = 0
SAMPLE_COUNT = 1_000

# Post-training QA.
AUDIT_CONVOY_PROFILE = CONVOY_PROFILE
AUDIT_CHECKPOINT_NAME = "model_best.pt"
TRAIN_COMPARE_LIMIT = 5_000
MIN_SPAWN_CLEARANCE_M_FOR_DECODED = MIN_SPAWN_CLEARANCE_M
VAE_SAMPLE_METHOD = "latent_bank"  # prior or latent_bank
LATENT_BANK_NOISE_SCALE = 0.10
DYNAMIC_AUDIT_T_MAX_S = 600.0
DYNAMIC_AUDIT_DT_S = 0.5

# %% [markdown]
# ## Helpers

# %%
def resolve_device(requested: str) -> str:
    if requested != "auto":
        return requested
    if torch.cuda.is_available():
        return "cuda"
    if hasattr(torch.backends, "mps") and torch.backends.mps.is_available():
        return "mps"
    return "cpu"


def seed_everything(seed: int) -> None:
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)


def mean_stats(stats_list: list[dict[str, float]]) -> dict[str, float]:
    if not stats_list:
        return {"loss": 0.0, "recon_loss": 0.0, "kl_loss": 0.0, "beta": 0.0}
    keys = stats_list[0].keys()
    return {key: float(np.mean([item[key] for item in stats_list], dtype=float)) for key in keys}


def train_one_epoch(model, data_loader, optimizer, device: str, beta: float) -> dict[str, float]:
    model.train()
    batch_stats = []
    for batch in data_loader:
        batch = batch.to(device)
        optimizer.zero_grad(set_to_none=True)
        recon, mu, logvar = model(batch)
        loss, stats = vae_loss(recon, batch, mu, logvar, beta=beta)
        loss.backward()
        optimizer.step()
        batch_stats.append(stats)
    return mean_stats(batch_stats)


def eval_one_epoch(model, data_loader, device: str, beta: float) -> dict[str, float]:
    model.eval()
    batch_stats = []
    with torch.no_grad():
        for batch in data_loader:
            batch = batch.to(device)
            recon, mu, logvar = model(batch)
            _, stats = vae_loss(recon, batch, mu, logvar, beta=beta)
            batch_stats.append(stats)
    return mean_stats(batch_stats)


def write_history_csv(path: Path, history: list[dict[str, float]]) -> None:
    ensure_dir(path.parent)
    fieldnames = [
        "epoch",
        "train_loss",
        "train_recon_loss",
        "train_kl_loss",
        "valid_loss",
        "valid_recon_loss",
        "valid_kl_loss",
    ]
    with path.open("w", newline="", encoding="utf-8") as handle:
        writer = csv.DictWriter(handle, fieldnames=fieldnames)
        writer.writeheader()
        for row in history:
            writer.writerow(row)

# %% [markdown]
# ## Dataset Generation (Split into Chunks)

# %%
def generate_dataset_jsonl(
    *,
    output_path: Path,
    count: int,
    seed: int,
    start_index: int,
    chunk_size: int,
    convoy_profile: str,
    mode: str,
    force: bool = False,
) -> Path:
    output_path = PROJECT_ROOT / output_path
    if output_path.exists() and not force:
        print(f"Using existing dataset: {output_path}")
        return output_path

    ensure_dir(output_path.parent)
    if output_path.exists():
        output_path.unlink()

    written = 0
    next_index = int(start_index)
    chunk_id = 0
    start = time.perf_counter()
    while written < int(count):
        chunk_count = min(int(chunk_size), int(count) - written)
        chunk_seed = int(seed) + chunk_id
        records, stats = generate_random_baseline_records(
            count=chunk_count,
            seed=chunk_seed,
            start_index=next_index,
            convoy_profile=convoy_profile,
            min_clearance_m=MIN_SPAWN_CLEARANCE_M,
        )
        with output_path.open("a", encoding="utf-8") as handle:
            for record in records:
                handle.write(json.dumps(record) + "\n")
        written += len(records)
        next_index += len(records)
        chunk_id += 1
        elapsed = time.perf_counter() - start
        print(f"{output_path.name}: wrote {written:,}/{count:,} records in {elapsed/60:.1f} min; last_chunk_acceptance={stats['acceptance_rate']:.3f}")
    return output_path


if GENERATE_DATASETS:
    generate_dataset_jsonl(
        output_path=TRAIN_PATH,
        count=TRAIN_COUNT,
        seed=TRAIN_SEED,
        start_index=1,
        chunk_size=GENERATION_CHUNK_SIZE,
        convoy_profile=CONVOY_PROFILE,
        mode=GENERATION_MODE,
        force=FORCE_REGENERATE_DATASETS,
    )
    generate_dataset_jsonl(
        output_path=VALID_PATH,
        count=VALID_COUNT,
        seed=VALID_SEED,
        start_index=TRAIN_COUNT + 1,
        chunk_size=GENERATION_CHUNK_SIZE,
        convoy_profile=CONVOY_PROFILE,
        mode=GENERATION_MODE,
        force=FORCE_REGENERATE_DATASETS,
    )
else:
    print("Dataset generation set to False!")
# Out:
# train_random_profile_v1_45k.jsonl: wrote 1,000/45,000 records in 2.2 min; last_chunk_acceptance=0.314
# train_random_profile_v1_45k.jsonl: wrote 2,000/45,000 records in 4.4 min; last_chunk_acceptance=0.327
# train_random_profile_v1_45k.jsonl: wrote 3,000/45,000 records in 6.6 min; last_chunk_acceptance=0.312
# train_random_profile_v1_45k.jsonl: wrote 4,000/45,000 records in 8.6 min; last_chunk_acceptance=0.314
# train_random_profile_v1_45k.jsonl: wrote 5,000/45,000 records in 10.5 min; last_chunk_acceptance=0.329
# train_random_profile_v1_45k.jsonl: wrote 6,000/45,000 records in 12.4 min; last_chunk_acceptance=0.329
# train_random_profile_v1_45k.jsonl: wrote 7,000/45,000 records in 14.3 min; last_chunk_acceptance=0.330
# train_random_profile_v1_45k.jsonl: wrote 8,000/45,000 records in 16.3 min; last_chunk_acceptance=0.308
# train_random_profile_v1_45k.jsonl: wrote 9,000/45,000 records in 18.4 min; last_chunk_acceptance=0.297
# train_random_profile_v1_45k.jsonl: wrote 10,000/45,000 records in 20.4 min; last_chunk_acceptance=0.319
# train_random_profile_v1_45k.jsonl: wrote 11,000/45,000 records in 22.4 min; last_chunk_acceptance=0.312
# train_random_profile_v1_45k.jsonl: wrote 12,000/45,000 records in 24.4 min; last_chunk_acceptance=0.312
# train_random_profile_v1_45k.jsonl: wrote 13,000/45,000 records in 26.5 min; last_chunk_acceptance=0.304
# train_random_profile_v1_45k.jsonl: wrote 14,000/45,000 records in 28.5 min; last_chunk_acceptance=0.313
# train_random_profile_v1_45k.jsonl: wrote 15,000/45,000 records in 30.6 min; last_chunk_acceptance=0.307
# train_random_profile_v1_45k.jsonl: wrote 16,000/45,000 records in 32.5 min; last_chunk_acceptance=0.329
# train_random_profile_v1_45k.jsonl: wrote 17,000/45,000 records in 34.5 min; last_chunk_acceptance=0.305
# train_random_profile_v1_45k.jsonl: wrote 18,000/45,000 records in 36.6 min; last_chunk_acceptance=0.310
# train_random_profile_v1_45k.jsonl: wrote 19,000/45,000 records in 38.6 min; last_chunk_acceptance=0.306
# train_random_profile_v1_45k.jsonl: wrote 20,000/45,000 records in 40.5 min; last_chunk_acceptance=0.334
# train_random_profile_v1_45k.jsonl: wrote 21,000/45,000 records in 42.6 min; last_chunk_acceptance=0.304
# train_random_profile_v1_45k.jsonl: wrote 22,000/45,000 records in 44.6 min; last_chunk_acceptance=0.318
# train_random_profile_v1_45k.jsonl: wrote 23,000/45,000 records in 46.6 min; last_chunk_acceptance=0.309
# train_random_profile_v1_45k.jsonl: wrote 24,000/45,000 records in 48.6 min; last_chunk_acceptance=0.318
# train_random_profile_v1_45k.jsonl: wrote 25,000/45,000 records in 50.6 min; last_chunk_acceptance=0.319
# train_random_profile_v1_45k.jsonl: wrote 26,000/45,000 records in 52.6 min; last_chunk_acceptance=0.319
# train_random_profile_v1_45k.jsonl: wrote 27,000/45,000 records in 54.7 min; last_chunk_acceptance=0.322
# train_random_profile_v1_45k.jsonl: wrote 28,000/45,000 records in 56.7 min; last_chunk_acceptance=0.313
# train_random_profile_v1_45k.jsonl: wrote 29,000/45,000 records in 58.8 min; last_chunk_acceptance=0.302
# train_random_profile_v1_45k.jsonl: wrote 30,000/45,000 records in 60.8 min; last_chunk_acceptance=0.306
# train_random_profile_v1_45k.jsonl: wrote 31,000/45,000 records in 62.9 min; last_chunk_acceptance=0.295
# train_random_profile_v1_45k.jsonl: wrote 32,000/45,000 records in 65.0 min; last_chunk_acceptance=0.298
# train_random_profile_v1_45k.jsonl: wrote 33,000/45,000 records in 67.0 min; last_chunk_acceptance=0.297
# train_random_profile_v1_45k.jsonl: wrote 34,000/45,000 records in 69.0 min; last_chunk_acceptance=0.313
# train_random_profile_v1_45k.jsonl: wrote 35,000/45,000 records in 71.1 min; last_chunk_acceptance=0.293
# train_random_profile_v1_45k.jsonl: wrote 36,000/45,000 records in 73.3 min; last_chunk_acceptance=0.321
# train_random_profile_v1_45k.jsonl: wrote 37,000/45,000 records in 75.3 min; last_chunk_acceptance=0.317
# train_random_profile_v1_45k.jsonl: wrote 38,000/45,000 records in 77.3 min; last_chunk_acceptance=0.313
# train_random_profile_v1_45k.jsonl: wrote 39,000/45,000 records in 79.4 min; last_chunk_acceptance=0.289
# train_random_profile_v1_45k.jsonl: wrote 40,000/45,000 records in 81.5 min; last_chunk_acceptance=0.306
# train_random_profile_v1_45k.jsonl: wrote 41,000/45,000 records in 83.4 min; last_chunk_acceptance=0.316
# train_random_profile_v1_45k.jsonl: wrote 42,000/45,000 records in 85.4 min; last_chunk_acceptance=0.308
# train_random_profile_v1_45k.jsonl: wrote 43,000/45,000 records in 87.4 min; last_chunk_acceptance=0.313
# train_random_profile_v1_45k.jsonl: wrote 44,000/45,000 records in 89.4 min; last_chunk_acceptance=0.306
# train_random_profile_v1_45k.jsonl: wrote 45,000/45,000 records in 91.4 min; last_chunk_acceptance=0.310
# valid_random_profile_v1_5k.jsonl: wrote 1,000/5,000 records in 2.0 min; last_chunk_acceptance=0.304
# valid_random_profile_v1_5k.jsonl: wrote 2,000/5,000 records in 4.1 min; last_chunk_acceptance=0.305
# valid_random_profile_v1_5k.jsonl: wrote 3,000/5,000 records in 6.2 min; last_chunk_acceptance=0.295
# valid_random_profile_v1_5k.jsonl: wrote 4,000/5,000 records in 8.1 min; last_chunk_acceptance=0.322
# valid_random_profile_v1_5k.jsonl: wrote 5,000/5,000 records in 10.1 min; last_chunk_acceptance=0.299

# %% [markdown]
# ## Dataset Sanity Check

# %%
def dataset_summary(path: Path, *, limit: int | None = None) -> dict:
    records = load_dataset_records(PROJECT_ROOT / path)
    inspect_records = records if limit is None else records[: int(limit)]
    flat_rows = flatten_dataset_records(inspect_records)
    summary = summarize_flat_rows(flat_rows)
    summary["path"] = str(path)
    summary["record_count_on_disk"] = len(records)
    return summary


missing = [str(path) for path in [PROJECT_ROOT / TRAIN_PATH, PROJECT_ROOT / VALID_PATH] if not path.exists()]
if missing:
    raise FileNotFoundError(
        "Missing dataset file(s): " + ", ".join(missing) + ". "
        "Set GENERATE_DATASETS = True, or update TRAIN_PATH / VALID_PATH."
    )

train_summary = dataset_summary(TRAIN_PATH, limit=TRAIN_COMPARE_LIMIT)
valid_summary = dataset_summary(VALID_PATH, limit=None)
train_summary, valid_summary
# Out:
# ({'profile_count': 5000,
#   'labels': {'credible_hit_threat': 3250,
#    'credible_near_miss': 1250,
#    'intentional_miss': 500},
#   'approach_families': {'unknown': 5000},
#   'range_bands': {'unknown': 5000},
#   'target_zone_kinds': {'profile_first_random': 5000},
#   'spawn_regions': {'ahead_random': 1256,
#    'inside_convoy_envelope': 1156,
#    'port_random': 773,
#    'astern_random': 989,
#    'starboard_random': 826},
#   'inside_convoy_envelope': {'true': 1156, 'false': 3844},
#   'approach_sides': {'ahead': 1256,
#    'inside': 1156,
#    'port': 773,
#    'astern': 989,
#    'starboard': 826},
#   'approach_lanes': {'ahead_random:random_ship': 692,
#    'ahead_random:convoy_center': 192,
#    'inside_convoy_envelope:random_convoy_box': 355,
#    'port_random:random_ship': 443,
#    'astern_random:random_ship': 504,
#    'ahead_random:random_convoy_box': 372,
#    'astern_random:random_convoy_box': 313,
#    'starboard_random:random_ship': 485,
#    'inside_convoy_envelope:random_ship': 612,
#    'inside_convoy_envelope:convoy_center': 189,
#    'starboard_random:convoy_center': 111,
#    'starboard_random:random_convoy_box': 230,
#    'astern_random:convoy_center': 172,
#    'port_random:convoy_center': 104,
#    'port_random:random_convoy_box': 226},
#   'spread_deg_values': {'5.2': 54,
#    '3.6': 95,
#    '7.0': 61,
#    '7.5': 62,
#    '3.3': 112,
#    '5.1': 60,
#    '8.0': 33,
#    '6.0': 74,
#    '6.7': 63,
#    '3.2': 112,
#    '3.7': 99,
#    '6.8': 62,
#    '3.5': 97,
#    '7.7': 66,
#    '2.5': 75,
#    '3.8': 110,
#    '7.1': 53,
#    '4.6': 91,
#    '2.2': 63,
#    '2.9': 92,
#    '4.1': 83,
#    '7.2': 59,
#    '4.7': 92,
#    '3.9': 96,
#    '3.4': 102,
#    '5.0': 66,
#    '5.8': 57,
#    '7.3': 70,
#    '1.9': 62,
#    '6.5': 56,
#    '7.6': 67,
#    '4.8': 99,
#    '2.8': 106,
#    '5.3': 68,
#    '5.4': 55,
#    '2.7': 117,
#    '5.7': 51,
#    '4.4': 94,
#    '5.9': 64,
#    '4.0': 95,
#    '1.8': 60,
#    '7.8': 53,
#    '5.5': 66,
#    '1.0': 8,
#    '5.6': 43,
#    '6.2': 68,
#    '6.9': 55,
#    '6.1': 63,
#    '3.0': 102,
#    '3.1': 112,
#    '4.2': 102,
#    '4.3': 91,
#    '7.9': 59,
#    '2.0': 58,
#    '4.9': 92,
#    '4.5': 106,
#    '1.2': 17,
#    '1.6': 91,
#    '6.3': 58,
#    '2.6': 98,
#    '2.1': 62,
#    '6.4': 70,
#    '7.4': 50,
#    '6.6': 64,
#    '1.5': 38,
#    '1.7': 73,
#    '2.4': 58,
#    '1.4': 11,
#    '2.3': 46,
#    '1.3': 15,
#    '1.1': 18},
#   'u_boat_speed_values_mps': {'1.4': 478,
#    '1.3': 460,
#    '1.5': 442,
#    '1.1': 434,
#    '1.6': 432,
#    '1.7': 455,
#    '1.8': 485,
#    '1.9': 443,
#    '2.0': 440,
#    '1.0': 435,
#    '1.2': 496},
#   'launch_delay_values_s': {'0.8': 235,
#    '1.1': 237,
#    '2.2': 274,
#    '1.5': 270,
#    '1.3': 252,
#    '1.7': 244,
#    '2.1': 202,
#    '0.7': 234,
#    '1.0': 236,
#    '2.3': 238,
#    '1.9': 251,
#    '2.5': 254,
#    '0.6': 235,
#    '1.2': 216,
#    '1.8': 227,
#    '0.5': 216,
#    '0.9': 222,
#    '2.0': 234,
#    '1.4': 227,
#    '1.6': 249,
#    '2.4': 247},
#   'salvo_interval_values_s': {'2.0': 1237,
#    '3.0': 1306,
#    '2.5': 1209,
#    '1.5': 1248},
#   'bearing_error_deg': {'mean': 13.300175779767105,
#    'min': 0.005041224450887897,
#    'max': 84.862946399422},
#   'range_to_centroid_m': {'mean': 5345.941985053625,
#    'min': 184.7593029237272,
#    'max': 11808.813282874746},
#   'range_to_target_m': {'mean': 5634.15256113729,
#    'min': 160.10090764280972,
#    'max': 15628.087687908823},
#   'severity': {'mean': 28.1902907082035,
#    'min': 0.006049469341065476,
#    'max': 100.0},
#   'top_10_highest_severity': [{'profile_id': 'R000023',
#     'name': 'random_profile_000023_port_random_random_ship',
#     'severity': 100.0,
#     'bearing_error_deg': 75.54271826012479,
#     'suggested_label': 'intentional_miss',
#     'approach_family': 'unknown',
#     'range_band': 'unknown',
#     'target_zone_kind': 'profile_first_random',
#     'spawn_region': 'port_random',
#     'approach_side': 'port'},
#    {'profile_id': 'R000049',
#     'name': 'random_profile_000049_ahead_random_random_ship',
#     'severity': 100.0,
#     'bearing_error_deg': 78.66181799774058,
#     'suggested_label': 'intentional_miss',
#     'approach_family': 'unknown',
#     'range_band': 'unknown',
#     'target_zone_kind': 'profile_first_random',
#     'spawn_region': 'ahead_random',
#     'approach_side': 'ahead'},
#    {'profile_id': 'R000056',
#     'name': 'random_profile_000056_starboard_random_random_ship',
#     'severity': 100.0,
#     'bearing_error_deg': 70.54582821696322,
#     'suggested_label': 'intentional_miss',
#     'approach_family': 'unknown',
#     'range_band': 'unknown',
#     'target_zone_kind': 'profile_first_random',
#     'spawn_region': 'starboard_random',
#     'approach_side': 'starboard'},
#    {'profile_id': 'R000061',
#     'name': 'random_profile_000061_starboard_random_random_convoy_box',
#     'severity': 100.0,
#     'bearing_error_deg': 78.79096928355227,
#     'suggested_label': 'intentional_miss',
#     'approach_family': 'unknown',
#     'range_band': 'unknown',
#     'target_zone_kind': 'profile_first_random',
#     'spawn_region': 'starboard_random',
#     'approach_side': 'starboard'},
#    {'profile_id': 'R000076',
#     'name': 'random_profile_000076_astern_random_convoy_center',
#     'severity': 100.0,
#     'bearing_error_deg': 76.77071638745062,
#     'suggested_label': 'intentional_miss',
#     'approach_family': 'unknown',
#     'range_band': 'unknown',
#     'target_zone_kind': 'profile_first_random',
#     'spawn_region': 'astern_random',
#     'approach_side': 'astern'},
#    {'profile_id': 'R000078',
#     'name': 'random_profile_000078_ahead_random_random_ship',
#     'severity': 100.0,
#     'bearing_error_deg': 70.09375422238001,
#     'suggested_label': 'intentional_miss',
#     'approach_family': 'unknown',
#     'range_band': 'unknown',
#     'target_zone_kind': 'profile_first_random',
#     'spawn_region': 'ahead_random',
#     'approach_side': 'ahead'},
#    {'profile_id': 'R000098',
#     'name': 'random_profile_000098_starboard_random_random_ship',
#     'severity': 100.0,
#     'bearing_error_deg': 69.30847380086414,
#     'suggested_label': 'intentional_miss',
#     'approach_family': 'unknown',
#     'range_band': 'unknown',
#     'target_zone_kind': 'profile_first_random',
#     'spawn_region': 'starboard_random',
#     'approach_side': 'starboard'},
#    {'profile_id': 'R000151',
#     'name': 'random_profile_000151_inside_convoy_envelope_random_convoy_box',
#     'severity': 100.0,
#     'bearing_error_deg': 72.90197401790287,
#     'suggested_label': 'intentional_miss',
#     'approach_family': 'unknown',
#     'range_band': 'unknown',
#     'target_zone_kind': 'profile_first_random',
#     'spawn_region': 'inside_convoy_envelope',
#     'approach_side': 'inside'},
#    {'profile_id': 'R000190',
#     'name': 'random_profile_000190_ahead_random_convoy_center',
#     'severity': 100.0,
#     'bearing_error_deg': 84.08594379189316,
#     'suggested_label': 'intentional_miss',
#     'approach_family': 'unknown',
#     'range_band': 'unknown',
#     'target_zone_kind': 'profile_first_random',
#     'spawn_region': 'ahead_random',
#     'approach_side': 'ahead'},
#    {'profile_id': 'R000195',
#     'name': 'random_profile_000195_starboard_random_random_ship',
#     'severity': 100.0,
#     'bearing_error_deg': 80.00641944725862,
#     'suggested_label': 'intentional_miss',
#     'approach_family': 'unknown',
#     'range_band': 'unknown',
#     'target_zone_kind': 'profile_first_random',
#     'spawn_region': 'starboard_random',
#     'approach_side': 'starboard'}],
#   'path': 'data/attack_profiles/synthetic/train_random_profile_v1_45k.jsonl',
#   'record_count_on_disk': 45000},
#  {'profile_count': 5000,
#   'labels': {'credible_hit_threat': 3250,
#    'intentional_miss': 500,
#    'credible_near_miss': 1250},
#   'approach_families': {'unknown': 5000},
#   'range_bands': {'unknown': 5000},
#   'target_zone_kinds': {'profile_first_random': 5000},
#   'spawn_regions': {'starboard_random': 809,
#    'ahead_random': 1246,
#    'port_random': 818,
#    'inside_convoy_envelope': 1196,
#    'astern_random': 931},
#   'inside_convoy_envelope': {'true': 1196, 'false': 3804},
#   'approach_sides': {'starboard': 809,
#    'ahead': 1246,
#    'port': 818,
#    'inside': 1196,
#    'astern': 931},
#   'approach_lanes': {'starboard_random:random_ship': 467,
#    'ahead_random:random_ship': 702,
#    'port_random:random_ship': 452,
#    'port_random:convoy_center': 126,
#    'inside_convoy_envelope:convoy_center': 187,
#    'inside_convoy_envelope:random_convoy_box': 381,
#    'astern_random:random_convoy_box': 288,
#    'port_random:random_convoy_box': 240,
#    'astern_random:random_ship': 487,
#    'ahead_random:random_convoy_box': 380,
#    'starboard_random:convoy_center': 120,
#    'inside_convoy_envelope:random_ship': 628,
#    'ahead_random:convoy_center': 164,
#    'starboard_random:random_convoy_box': 222,
#    'astern_random:convoy_center': 156},
#   'spread_deg_values': {'6.0': 61,
#    '7.0': 51,
#    '2.4': 63,
#    '2.0': 67,
#    '5.5': 65,
#    '7.2': 54,
#    '5.2': 67,
#    '2.6': 118,
#    '7.4': 61,
#    '7.8': 47,
#    '5.3': 68,
#    '3.2': 107,
#    '3.1': 121,
#    '4.6': 94,
#    '2.3': 43,
#    '4.4': 98,
#    '7.3': 55,
#    '5.6': 69,
#    '3.9': 107,
#    '7.5': 54,
#    '4.0': 99,
#    '3.6': 95,
#    '5.1': 68,
#    '7.7': 56,
#    '7.6': 57,
#    '2.5': 72,
#    '5.0': 72,
#    '4.1': 84,
#    '5.9': 63,
#    '6.6': 45,
#    '4.9': 74,
#    '4.2': 102,
#    '4.7': 71,
#    '3.4': 119,
#    '4.5': 86,
#    '4.8': 104,
#    '1.7': 68,
#    '5.8': 64,
#    '3.8': 104,
#    '8.0': 34,
#    '2.2': 53,
#    '5.7': 56,
#    '1.4': 21,
#    '2.9': 105,
#    '3.0': 109,
#    '7.9': 62,
#    '3.5': 121,
#    '6.2': 64,
#    '6.5': 67,
#    '3.7': 113,
#    '2.7': 105,
#    '6.8': 61,
#    '6.3': 58,
#    '6.1': 66,
#    '6.4': 59,
#    '2.8': 105,
#    '6.9': 53,
#    '7.1': 54,
#    '3.3': 94,
#    '4.3': 87,
#    '1.8': 67,
#    '1.5': 41,
#    '1.6': 67,
#    '1.2': 18,
#    '1.9': 62,
#    '6.7': 65,
#    '2.1': 65,
#    '1.3': 17,
#    '5.4': 52,
#    '1.1': 19,
#    '1.0': 7},
#   'u_boat_speed_values_mps': {'1.6': 448,
#    '1.7': 455,
#    '1.8': 407,
#    '1.1': 504,
#    '1.3': 470,
#    '1.9': 508,
#    '1.5': 438,
#    '1.2': 441,
#    '2.0': 424,
#    '1.0': 458,
#    '1.4': 447},
#   'launch_delay_values_s': {'0.6': 257,
#    '2.3': 209,
#    '0.5': 255,
#    '0.8': 240,
#    '2.1': 227,
#    '1.8': 232,
#    '1.7': 223,
#    '0.9': 238,
#    '2.4': 241,
#    '2.5': 241,
#    '1.2': 234,
#    '1.4': 233,
#    '1.9': 268,
#    '1.3': 230,
#    '1.0': 254,
#    '1.6': 258,
#    '1.1': 232,
#    '2.0': 220,
#    '1.5': 229,
#    '0.7': 243,
#    '2.2': 236},
#   'salvo_interval_values_s': {'1.5': 1232,
#    '3.0': 1228,
#    '2.5': 1317,
#    '2.0': 1223},
#   'bearing_error_deg': {'mean': 13.443491408370416,
#    'min': 0.0010955662058343613,
#    'max': 84.95670719873824},
#   'range_to_centroid_m': {'mean': 5400.4516908565765,
#    'min': 195.58316958077413,
#    'max': 11944.531564820936},
#   'range_to_target_m': {'mean': 5728.412203441347,
#    'min': 78.14199991340651,
#    'max': 15926.154372934221},
#   'severity': {'mean': 28.539300260235482,
#    'min': 0.0013146794470012336,
#    'max': 100.0},
#   'top_10_highest_severity': [{'profile_id': 'R045003',
#     'name': 'random_profile_045003_ahead_random_random_ship',
#     'severity': 100.0,
#     'bearing_error_deg': 74.15402481105468,
#     'suggested_label': 'intentional_miss',
#     'approach_family': 'unknown',
#     'range_band': 'unknown',
#     'target_zone_kind': 'profile_first_random',
#     'spawn_region': 'ahead_random',
#     'approach_side': 'ahead'},
#    {'profile_id': 'R045004',
#     'name': 'random_profile_045004_port_random_random_ship',
#     'severity': 100.0,
#     'bearing_error_deg': 68.40336108871341,
#     'suggested_label': 'intentional_miss',
#     'approach_family': 'unknown',
#     'range_band': 'unknown',
#     'target_zone_kind': 'profile_first_random',
#     'spawn_region': 'port_random',
#     'approach_side': 'port'},
#    {'profile_id': 'R045031',
#     'name': 'random_profile_045031_astern_random_random_convoy_box',
#     'severity': 100.0,
#     'bearing_error_deg': 68.25207420644115,
#     'suggested_label': 'intentional_miss',
#     'approach_family': 'unknown',
#     'range_band': 'unknown',
#     'target_zone_kind': 'profile_first_random',
#     'spawn_region': 'astern_random',
#     'approach_side': 'astern'},
#    {'profile_id': 'R045042',
#     'name': 'random_profile_045042_ahead_random_random_ship',
#     'severity': 100.0,
#     'bearing_error_deg': 80.09151390665431,
#     'suggested_label': 'intentional_miss',
#     'approach_family': 'unknown',
#     'range_band': 'unknown',
#     'target_zone_kind': 'profile_first_random',
#     'spawn_region': 'ahead_random',
#     'approach_side': 'ahead'},
#    {'profile_id': 'R045047',
#     'name': 'random_profile_045047_astern_random_random_convoy_box',
#     'severity': 100.0,
#     'bearing_error_deg': 69.39093765956808,
#     'suggested_label': 'intentional_miss',
#     'approach_family': 'unknown',
#     'range_band': 'unknown',
#     'target_zone_kind': 'profile_first_random',
#     'spawn_region': 'astern_random',
#     'approach_side': 'astern'},
#    {'profile_id': 'R045056',
#     'name': 'random_profile_045056_astern_random_random_ship',
#     'severity': 100.0,
#     'bearing_error_deg': 83.32178467689646,
#     'suggested_label': 'intentional_miss',
#     'approach_family': 'unknown',
#     'range_band': 'unknown',
#     'target_zone_kind': 'profile_first_random',
#     'spawn_region': 'astern_random',
#     'approach_side': 'astern'},
#    {'profile_id': 'R045153',
#     'name': 'random_profile_045153_starboard_random_random_ship',
#     'severity': 100.0,
#     'bearing_error_deg': 81.24814592030042,
#     'suggested_label': 'intentional_miss',
#     'approach_family': 'unknown',
#     'range_band': 'unknown',
#     'target_zone_kind': 'profile_first_random',
#     'spawn_region': 'starboard_random',
#     'approach_side': 'starboard'},
#    {'profile_id': 'R045207',
#     'name': 'random_profile_045207_inside_convoy_envelope_random_convoy_box',
#     'severity': 100.0,
#     'bearing_error_deg': 78.05964508254733,
#     'suggested_label': 'intentional_miss',
#     'approach_family': 'unknown',
#     'range_band': 'unknown',
#     'target_zone_kind': 'profile_first_random',
#     'spawn_region': 'inside_convoy_envelope',
#     'approach_side': 'inside'},
#    {'profile_id': 'R045209',
#     'name': 'random_profile_045209_starboard_random_random_ship',
#     'severity': 100.0,
#     'bearing_error_deg': 80.21036084033824,
#     'suggested_label': 'intentional_miss',
#     'approach_family': 'unknown',
#     'range_band': 'unknown',
#     'target_zone_kind': 'profile_first_random',
#     'spawn_region': 'starboard_random',
#     'approach_side': 'starboard'},
#    {'profile_id': 'R045225',
#     'name': 'random_profile_045225_inside_convoy_envelope_convoy_center',
#     'severity': 100.0,
#     'bearing_error_deg': 83.38006701746062,
#     'suggested_label': 'intentional_miss',
#     'approach_family': 'unknown',
#     'range_band': 'unknown',
#     'target_zone_kind': 'profile_first_random',
#     'spawn_region': 'inside_convoy_envelope',
#     'approach_side': 'inside'}],
#   'path': 'data/attack_profiles/synthetic/valid_random_profile_v1_5k.jsonl',
#   'record_count_on_disk': 5000})

# %%
train_records_preview = load_dataset_records(PROJECT_ROOT / TRAIN_PATH)[: int(TRAIN_COMPARE_LIMIT)]
train_rows_preview = flatten_dataset_records(train_records_preview)
train_df_preview = pd.DataFrame(train_rows_preview)

fig, axes = plt.subplots(1, 3, figsize=(15, 4), facecolor="lightgrey")
for ax, column, title in [
    (axes[0], "suggested_label", "Labels"),
    (axes[1], "spawn_region", "Spawn region"),
    (axes[2], "target_zone_kind", "Target zone"),
]:
    ax.set_facecolor("lightgrey")
    counts = train_df_preview[column].value_counts().sort_index()
    counts.plot(kind="bar", ax=ax, color="#06768d")
    ax.set_title(title)
    ax.set_ylabel("count")
    ax.tick_params(axis="x", rotation=45)
    for spine in ax.spines.values():
        spine.set_visible(False)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Training

# %%
def run_training_notebook() -> Path:
    overall_start = time.perf_counter()
    seed_everything(int(SEED))
    device = resolve_device(DEVICE)
    output_root = PROJECT_ROOT / OUTPUT_ROOT
    run_dir = resolve_run_dir(output_root, "vae", RUN_NAME)
    checkpoint_dir = run_dir / "checkpoints"
    ensure_dir(checkpoint_dir)

    data_start = time.perf_counter()
    train_ds, valid_ds, preprocessor = build_vae_datasets(
        train_path=PROJECT_ROOT / TRAIN_PATH,
        valid_path=PROJECT_ROOT / VALID_PATH,
    )
    data_seconds = time.perf_counter() - data_start

    generator = torch.Generator().manual_seed(int(SEED))
    train_loader = DataLoader(
        train_ds,
        batch_size=int(BATCH_SIZE),
        shuffle=True,
        generator=generator,
        num_workers=int(NUM_WORKERS),
    )
    valid_loader = DataLoader(
        valid_ds,
        batch_size=int(BATCH_SIZE),
        shuffle=False,
        num_workers=int(NUM_WORKERS),
    )

    model = AttackProfileVAE(latent_dim=int(LATENT_DIM), hidden_dim=int(HIDDEN_DIM)).to(device)
    optimizer = Adam(model.parameters(), lr=float(LEARNING_RATE))

    history = []
    best_valid_loss = float("inf")
    best_epoch = 0
    train_start = time.perf_counter()

    for epoch in range(1, int(EPOCHS) + 1):
        train_stats = train_one_epoch(model, train_loader, optimizer, device, float(BETA))
        valid_stats = eval_one_epoch(model, valid_loader, device, float(BETA))
        row = {
            "epoch": int(epoch),
            "train_loss": float(train_stats["loss"]),
            "train_recon_loss": float(train_stats["recon_loss"]),
            "train_kl_loss": float(train_stats["kl_loss"]),
            "valid_loss": float(valid_stats["loss"]),
            "valid_recon_loss": float(valid_stats["recon_loss"]),
            "valid_kl_loss": float(valid_stats["kl_loss"]),
        }
        history.append(row)
        best_marker = ""
        if row["valid_loss"] < best_valid_loss:
            best_valid_loss = row["valid_loss"]
            best_epoch = int(epoch)
            best_marker = " *best"
            torch.save({
                "epoch": best_epoch,
                "model_state_dict": model.state_dict(),
                "optimizer_state_dict": optimizer.state_dict(),
                "preprocessor": preprocessor.to_dict(),
                "hyperparameters": {
                    "latent_dim": int(LATENT_DIM),
                    "hidden_dim": int(HIDDEN_DIM),
                    "learning_rate": float(LEARNING_RATE),
                    "batch_size": int(BATCH_SIZE),
                    "beta": float(BETA),
                },
            }, checkpoint_dir / "model_best.pt")
        print(
            f"epoch {epoch:03d} | "
            f"train_loss={row['train_loss']:.4f} "
            f"train_recon={row['train_recon_loss']:.4f} "
            f"train_kl={row['train_kl_loss']:.4f} | "
            f"valid_loss={row['valid_loss']:.4f} "
            f"valid_recon={row['valid_recon_loss']:.4f} "
            f"valid_kl={row['valid_kl_loss']:.4f}"
            f"{best_marker}"
        )

    training_seconds = time.perf_counter() - train_start
    torch.save({
        "epoch": int(EPOCHS),
        "model_state_dict": model.state_dict(),
        "optimizer_state_dict": optimizer.state_dict(),
        "preprocessor": preprocessor.to_dict(),
        "hyperparameters": {
            "latent_dim": int(LATENT_DIM),
            "hidden_dim": int(HIDDEN_DIM),
            "learning_rate": float(LEARNING_RATE),
            "batch_size": int(BATCH_SIZE),
            "beta": float(BETA),
        },
    }, checkpoint_dir / "model_latest.pt")

    sample_start = time.perf_counter()
    model.eval()
    sample_device = torch.device(device)
    if str(VAE_SAMPLE_METHOD) == "prior":
        with torch.no_grad():
            decoded = model.sample(int(SAMPLE_COUNT), device=sample_device).cpu().numpy()
    elif str(VAE_SAMPLE_METHOD) == "latent_bank":
        latent_bank = build_latent_bank(model, train_ds.features, device=sample_device)
        with torch.no_grad():
            decoded = model.sample_from_latent_bank(
                latent_bank,
                int(SAMPLE_COUNT),
                noise_scale=float(LATENT_BANK_NOISE_SCALE),
                device=sample_device,
            ).cpu().numpy()
    else:
        raise ValueError("VAE_SAMPLE_METHOD must be 'prior' or 'latent_bank'")
    sample_payload = [
        preprocessor.decode_profile_fields(
            decoded[idx],
            profile_id=f"VAE_SAMPLE_{idx + 1:04d}",
            name=f"vae_sample_{idx + 1:04d}",
        )
        for idx in range(int(SAMPLE_COUNT))
    ]
    sample_seconds = time.perf_counter() - sample_start

    write_history_csv(run_dir / "training_history.csv", history)
    write_json(run_dir / "sampled_profiles.json", {"profiles": sample_payload})

    final_train = history[-1]
    best_row = history[best_epoch - 1]
    metrics_summary = {
        "dataset": {
            "train_samples": int(len(train_ds)),
            "valid_samples": int(len(valid_ds)),
            "input_dim": int(model.input_dim),
            "feature_names": list(preprocessor.feature_names),
        },
        "model": {
            "latent_dim": int(model.latent_dim),
            "hidden_dim": int(model.hidden_dim),
            "parameter_count": int(sum(int(p.numel()) for p in model.parameters())),
            "beta": float(BETA),
        },
        "training": {
            "epochs": int(EPOCHS),
            "batch_size": int(BATCH_SIZE),
            "learning_rate": float(LEARNING_RATE),
            "best_epoch": int(best_epoch),
            "final_train_loss": float(final_train["train_loss"]),
            "final_train_recon_loss": float(final_train["train_recon_loss"]),
            "final_train_kl_loss": float(final_train["train_kl_loss"]),
            "final_valid_loss": float(final_train["valid_loss"]),
            "final_valid_recon_loss": float(final_train["valid_recon_loss"]),
            "final_valid_kl_loss": float(final_train["valid_kl_loss"]),
            "best_valid_loss": float(best_row["valid_loss"]),
            "best_valid_recon_loss": float(best_row["valid_recon_loss"]),
            "best_valid_kl_loss": float(best_row["valid_kl_loss"]),
        },
        "samples": {
            "count": int(SAMPLE_COUNT),
            "sampling_method": str(VAE_SAMPLE_METHOD),
            "latent_noise_scale": float(LATENT_BANK_NOISE_SCALE),
            "output_file": "sampled_profiles.json",
        },
        "timing": {
            "dataset_load_seconds": float(data_seconds),
            "training_seconds": float(training_seconds),
            "sample_decode_seconds": float(sample_seconds),
            "total_seconds": float(time.perf_counter() - overall_start),
        },
    }
    manifest = {
        "workflow": "vae_train_notebook",
        "git_sha": git_sha(PROJECT_ROOT),
        "device": device,
        "seed": int(SEED),
        "train_path": str(TRAIN_PATH),
        "valid_path": str(VALID_PATH),
        "output_root": str(OUTPUT_ROOT),
        "run_name": str(RUN_NAME),
        "hyperparameters": {
            "epochs": int(EPOCHS),
            "batch_size": int(BATCH_SIZE),
            "learning_rate": float(LEARNING_RATE),
            "beta": float(BETA),
            "latent_dim": int(LATENT_DIM),
            "hidden_dim": int(HIDDEN_DIM),
            "sample_count": int(SAMPLE_COUNT),
            "sample_method": str(VAE_SAMPLE_METHOD),
            "latent_noise_scale": float(LATENT_BANK_NOISE_SCALE),
        },
        "preprocessor": preprocessor.to_dict(),
        "artifacts": {
            "history_csv": "training_history.csv",
            "metrics_summary_json": "metrics_summary.json",
            "run_manifest_json": "run_manifest.json",
            "best_checkpoint": "checkpoints/model_best.pt",
            "latest_checkpoint": "checkpoints/model_latest.pt",
            "sampled_profiles_json": "sampled_profiles.json",
        },
    }
    resolved_cfg = {
        "dataset": {
            "train_path": str(TRAIN_PATH),
            "valid_path": str(VALID_PATH),
        },
        "training": {
            "epochs": int(EPOCHS),
            "batch_size": int(BATCH_SIZE),
            "learning_rate": float(LEARNING_RATE),
            "beta": float(BETA),
            "latent_dim": int(LATENT_DIM),
            "hidden_dim": int(HIDDEN_DIM),
            "device": device,
            "num_workers": int(NUM_WORKERS),
            "sample_count": int(SAMPLE_COUNT),
            "seed": int(SEED),
        },
    }

    write_yaml(run_dir / "config_resolved.yaml", resolved_cfg)
    write_json(run_dir / "metrics_summary.json", metrics_summary)
    write_json(run_dir / "run_manifest.json", manifest)
    return run_dir

# %%
if RUN_TRAINING:
    RUN_DIR = run_training_notebook()
else:
    RUN_DIR = PROJECT_ROOT / EXISTING_RUN_DIR
    if not RUN_DIR.exists():
        raise ValueError("Set EXISTING_RUN_DIR to an existing run when RUN_TRAINING is False")

RUN_DIR
# Out:
# epoch 001 | train_loss=0.8057 train_recon=0.7385 train_kl=2.2398 | valid_loss=0.5759 valid_recon=0.4385 valid_kl=4.5810 *best
# epoch 002 | train_loss=0.4709 train_recon=0.2991 train_kl=5.7242 | valid_loss=0.4369 valid_recon=0.2592 valid_kl=5.9231 *best
# epoch 003 | train_loss=0.3850 train_recon=0.1881 train_kl=6.5622 | valid_loss=0.3580 valid_recon=0.1518 valid_kl=6.8725 *best
# epoch 004 | train_loss=0.3553 train_recon=0.1493 train_kl=6.8679 | valid_loss=0.3516 valid_recon=0.1425 valid_kl=6.9702 *best
# epoch 005 | train_loss=0.3505 train_recon=0.1449 train_kl=6.8553 | valid_loss=0.3480 valid_recon=0.1420 valid_kl=6.8664 *best
# epoch 006 | train_loss=0.3467 train_recon=0.1402 train_kl=6.8852 | valid_loss=0.3447 valid_recon=0.1356 valid_kl=6.9715 *best
# epoch 007 | train_loss=0.3429 train_recon=0.1361 train_kl=6.8937 | valid_loss=0.3414 valid_recon=0.1413 valid_kl=6.6705 *best
# epoch 008 | train_loss=0.3406 train_recon=0.1336 train_kl=6.9018 | valid_loss=0.3401 valid_recon=0.1327 valid_kl=6.9125 *best
# epoch 009 | train_loss=0.3387 train_recon=0.1313 train_kl=6.9116 | valid_loss=0.3376 valid_recon=0.1318 valid_kl=6.8583 *best
# epoch 010 | train_loss=0.3372 train_recon=0.1299 train_kl=6.9084 | valid_loss=0.3366 valid_recon=0.1320 valid_kl=6.8189 *best
# epoch 011 | train_loss=0.3357 train_recon=0.1287 train_kl=6.9001 | valid_loss=0.3355 valid_recon=0.1270 valid_kl=6.9506 *best
# epoch 012 | train_loss=0.3344 train_recon=0.1269 train_kl=6.9144 | valid_loss=0.3340 valid_recon=0.1284 valid_kl=6.8542 *best
# epoch 013 | train_loss=0.3341 train_recon=0.1265 train_kl=6.9209 | valid_loss=0.3336 valid_recon=0.1272 valid_kl=6.8781 *best
# epoch 014 | train_loss=0.3338 train_recon=0.1257 train_kl=6.9384 | valid_loss=0.3319 valid_recon=0.1230 valid_kl=6.9643 *best
# epoch 015 | train_loss=0.3327 train_recon=0.1249 train_kl=6.9249 | valid_loss=0.3322 valid_recon=0.1237 valid_kl=6.9518
# epoch 016 | train_loss=0.3321 train_recon=0.1239 train_kl=6.9411 | valid_loss=0.3317 valid_recon=0.1250 valid_kl=6.8923 *best
# epoch 017 | train_loss=0.3325 train_recon=0.1235 train_kl=6.9673 | valid_loss=0.3312 valid_recon=0.1222 valid_kl=6.9680 *best
# epoch 018 | train_loss=0.3308 train_recon=0.1229 train_kl=6.9326 | valid_loss=0.3331 valid_recon=0.1275 valid_kl=6.8537
# epoch 019 | train_loss=0.3310 train_recon=0.1225 train_kl=6.9513 | valid_loss=0.3308 valid_recon=0.1210 valid_kl=6.9925 *best
# epoch 020 | train_loss=0.3301 train_recon=0.1215 train_kl=6.9532 | valid_loss=0.3306 valid_recon=0.1192 valid_kl=7.0441 *best
# epoch 021 | train_loss=0.3298 train_recon=0.1211 train_kl=6.9587 | valid_loss=0.3288 valid_recon=0.1188 valid_kl=7.0029 *best
# epoch 022 | train_loss=0.3294 train_recon=0.1206 train_kl=6.9595 | valid_loss=0.3309 valid_recon=0.1219 valid_kl=6.9667
# epoch 023 | train_loss=0.3296 train_recon=0.1201 train_kl=6.9820 | valid_loss=0.3297 valid_recon=0.1220 valid_kl=6.9229
# epoch 024 | train_loss=0.3288 train_recon=0.1199 train_kl=6.9649 | valid_loss=0.3286 valid_recon=0.1187 valid_kl=6.9973 *best
# epoch 025 | train_loss=0.3289 train_recon=0.1198 train_kl=6.9705 | valid_loss=0.3288 valid_recon=0.1189 valid_kl=6.9966
# epoch 026 | train_loss=0.3281 train_recon=0.1191 train_kl=6.9664 | valid_loss=0.3285 valid_recon=0.1189 valid_kl=6.9858 *best
# epoch 027 | train_loss=0.3277 train_recon=0.1185 train_kl=6.9751 | valid_loss=0.3303 valid_recon=0.1234 valid_kl=6.8983
# epoch 028 | train_loss=0.3279 train_recon=0.1188 train_kl=6.9705 | valid_loss=0.3260 valid_recon=0.1193 valid_kl=6.8900 *best
# epoch 029 | train_loss=0.3282 train_recon=0.1183 train_kl=6.9963 | valid_loss=0.3282 valid_recon=0.1204 valid_kl=6.9285
# epoch 030 | train_loss=0.3275 train_recon=0.1180 train_kl=6.9831 | valid_loss=0.3278 valid_recon=0.1178 valid_kl=6.9978
# epoch 031 | train_loss=0.3282 train_recon=0.1180 train_kl=7.0049 | valid_loss=0.3270 valid_recon=0.1163 valid_kl=7.0218
# epoch 032 | train_loss=0.3267 train_recon=0.1171 train_kl=6.9882 | valid_loss=0.3270 valid_recon=0.1138 valid_kl=7.1053
# epoch 033 | train_loss=0.3267 train_recon=0.1169 train_kl=6.9933 | valid_loss=0.3257 valid_recon=0.1155 valid_kl=7.0089 *best
# epoch 034 | train_loss=0.3266 train_recon=0.1170 train_kl=6.9869 | valid_loss=0.3271 valid_recon=0.1156 valid_kl=7.0515
# epoch 035 | train_loss=0.3264 train_recon=0.1164 train_kl=6.9992 | valid_loss=0.3258 valid_recon=0.1113 valid_kl=7.1492
# epoch 036 | train_loss=0.3258 train_recon=0.1163 train_kl=6.9859 | valid_loss=0.3256 valid_recon=0.1115 valid_kl=7.1386 *best
# epoch 037 | train_loss=0.3258 train_recon=0.1157 train_kl=7.0021 | valid_loss=0.3244 valid_recon=0.1136 valid_kl=7.0253 *best
# epoch 038 | train_loss=0.3262 train_recon=0.1158 train_kl=7.0140 | valid_loss=0.3261 valid_recon=0.1152 valid_kl=7.0283
# epoch 039 | train_loss=0.3254 train_recon=0.1157 train_kl=6.9904 | valid_loss=0.3268 valid_recon=0.1179 valid_kl=6.9624
# epoch 040 | train_loss=0.3255 train_recon=0.1155 train_kl=7.0001 | valid_loss=0.3264 valid_recon=0.1166 valid_kl=6.9940
# epoch 041 | train_loss=0.3256 train_recon=0.1154 train_kl=7.0056 | valid_loss=0.3243 valid_recon=0.1134 valid_kl=7.0299 *best
# epoch 042 | train_loss=0.3254 train_recon=0.1151 train_kl=7.0096 | valid_loss=0.3251 valid_recon=0.1167 valid_kl=6.9471
# epoch 043 | train_loss=0.3248 train_recon=0.1149 train_kl=6.9968 | valid_loss=0.3256 valid_recon=0.1170 valid_kl=6.9511
# epoch 044 | train_loss=0.3243 train_recon=0.1146 train_kl=6.9898 | valid_loss=0.3242 valid_recon=0.1123 valid_kl=7.0616 *best
# epoch 045 | train_loss=0.3245 train_recon=0.1143 train_kl=7.0064 | valid_loss=0.3262 valid_recon=0.1169 valid_kl=6.9786
# epoch 046 | train_loss=0.3243 train_recon=0.1143 train_kl=6.9988 | valid_loss=0.3254 valid_recon=0.1106 valid_kl=7.1604
# epoch 047 | train_loss=0.3245 train_recon=0.1143 train_kl=7.0076 | valid_loss=0.3237 valid_recon=0.1117 valid_kl=7.0643 *best
# epoch 048 | train_loss=0.3247 train_recon=0.1141 train_kl=7.0209 | valid_loss=0.3239 valid_recon=0.1121 valid_kl=7.0606
# epoch 049 | train_loss=0.3237 train_recon=0.1135 train_kl=7.0059 | valid_loss=0.3237 valid_recon=0.1147 valid_kl=6.9664 *best
# epoch 050 | train_loss=0.3238 train_recon=0.1135 train_kl=7.0085 | valid_loss=0.3233 valid_recon=0.1145 valid_kl=6.9615 *best
# epoch 051 | train_loss=0.3236 train_recon=0.1134 train_kl=7.0082 | valid_loss=0.3226 valid_recon=0.1130 valid_kl=6.9879 *best
# epoch 052 | train_loss=0.3232 train_recon=0.1133 train_kl=6.9986 | valid_loss=0.3258 valid_recon=0.1160 valid_kl=6.9931
# epoch 053 | train_loss=0.3228 train_recon=0.1128 train_kl=6.9998 | valid_loss=0.3220 valid_recon=0.1096 valid_kl=7.0779 *best
# epoch 054 | train_loss=0.3228 train_recon=0.1128 train_kl=7.0008 | valid_loss=0.3224 valid_recon=0.1135 valid_kl=6.9608
# epoch 055 | train_loss=0.3229 train_recon=0.1126 train_kl=7.0085 | valid_loss=0.3234 valid_recon=0.1111 valid_kl=7.0743
# epoch 056 | train_loss=0.3228 train_recon=0.1127 train_kl=7.0033 | valid_loss=0.3236 valid_recon=0.1140 valid_kl=6.9842
# epoch 057 | train_loss=0.3226 train_recon=0.1127 train_kl=6.9967 | valid_loss=0.3234 valid_recon=0.1126 valid_kl=7.0267
# epoch 058 | train_loss=0.3226 train_recon=0.1123 train_kl=7.0073 | valid_loss=0.3222 valid_recon=0.1125 valid_kl=6.9916
# epoch 059 | train_loss=0.3223 train_recon=0.1121 train_kl=7.0054 | valid_loss=0.3237 valid_recon=0.1103 valid_kl=7.1147
# epoch 060 | train_loss=0.3221 train_recon=0.1122 train_kl=6.9957 | valid_loss=0.3225 valid_recon=0.1128 valid_kl=6.9892
# PosixPath('/Users/matthewplambeck/Desktop/Convoy Layout Project/results/runs/vae/20260511_161735_random_v1_notebook')

# %% [markdown]
# ## Training History

# %%
history_df = pd.read_csv(RUN_DIR / "training_history.csv")
metrics_summary = json.loads((RUN_DIR / "metrics_summary.json").read_text(encoding="utf-8"))
metrics_summary
# Out:
# {'dataset': {'train_samples': 45000,
#   'valid_samples': 5000,
#   'input_dim': 8,
#   'feature_names': ['u_pos_x',
#    'u_pos_y',
#    'sin_base_bearing_rad',
#    'cos_base_bearing_rad',
#    'spread_rad',
#    'launch_delay_s',
#    'salvo_interval_s',
#    'u_boat_initial_speed_mps']},
#  'model': {'latent_dim': 6,
#   'hidden_dim': 64,
#   'parameter_count': 10644,
#   'beta': 0.03},
#  'training': {'epochs': 60,
#   'batch_size': 512,
#   'learning_rate': 0.001,
#   'best_epoch': 53,
#   'final_train_loss': 0.322103793986819,
#   'final_train_recon_loss': 0.11223415124484083,
#   'final_train_kl_loss': 6.9956549189307475,
#   'final_valid_loss': 0.32250926494598386,
#   'final_valid_recon_loss': 0.11283246502280235,
#   'final_valid_kl_loss': 6.989226961135865,
#   'best_valid_loss': 0.3219811677932739,
#   'best_valid_recon_loss': 0.10964278727769852,
#   'best_valid_kl_loss': 7.0779460906982425},
#  'samples': {'count': 1000,
#   'sampling_method': 'latent_bank',
#   'latent_noise_scale': 0.1,
#   'output_file': 'sampled_profiles.json'},
#  'timing': {'dataset_load_seconds': 3.771315542049706,
#   'training_seconds': 32.02974120806903,
#   'sample_decode_seconds': 0.42865495942533016,
#   'total_seconds': 37.38584804069251}}

# %%
fig, axes = plt.subplots(1, 2, figsize=(13, 4), facecolor="lightgrey")
#Left Plot
axes[0].plot(history_df["epoch"], history_df["train_loss"], label="train")
axes[0].plot(history_df["epoch"], history_df["valid_loss"], label="valid")
axes[0].set_title("Total loss")
axes[0].set_xlabel("epoch")
axes[0].legend(frameon=False)
#Right Plot
axes[1].plot(history_df["epoch"], history_df["train_recon_loss"], label="train recon")
axes[1].plot(history_df["epoch"], history_df["valid_recon_loss"], label="valid recon")
axes[1].plot(history_df["epoch"], history_df["train_kl_loss"], label="train KL", alpha=0.7)
axes[1].plot(history_df["epoch"], history_df["valid_kl_loss"], label="valid KL", alpha=0.7)
axes[1].set_title("Components")
axes[1].set_xlabel("epoch")
axes[1].legend(frameon=False)
for ax in axes:
    ax.set_facecolor("lightgrey")
    for spine in ax.spines.values():
        spine.set_visible(False)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Sample From Checkpoint
#
# Decoded VAE samples do not currently include target intent labels. The audit below is therefore a coarse geometry sanity check, not a replacement for the v4 outcome-gated data-generation audit.

# %%
def sample_profiles_from_checkpoint(
    run_dir: Path,
    *,
    checkpoint_name: str,
    sample_count: int,
    device: str = "cpu",
    sampling_method: str = "prior",
    train_path: Path | None = None,
    latent_noise_scale: float = 0.10,
    seed: int = 1945,
) -> tuple[list[dict], AttackProfileVAEPreprocessor, dict]:
    manifest = json.loads((run_dir / "run_manifest.json").read_text(encoding="utf-8"))
    checkpoint = torch.load(run_dir / "checkpoints" / checkpoint_name, map_location=device)
    preprocessor_payload = checkpoint.get("preprocessor", manifest["preprocessor"])
    preprocessor = AttackProfileVAEPreprocessor.from_dict(preprocessor_payload)
    hyper = checkpoint.get("hyperparameters", manifest["hyperparameters"])
    model = AttackProfileVAE(latent_dim=int(hyper["latent_dim"]), hidden_dim=int(hyper["hidden_dim"]))
    model.load_state_dict(checkpoint["model_state_dict"])
    model.to(device)
    model.eval()

    sample_device = torch.device(device)
    torch.manual_seed(int(seed))
    if str(sampling_method) == "prior":
        with torch.no_grad():
            decoded = model.sample(int(sample_count), device=sample_device).cpu().numpy()
    elif str(sampling_method) == "latent_bank":
        if train_path is None:
            raise ValueError("train_path is required for latent_bank sampling")
        train_records_for_bank = load_attack_profile_dataset_jsonl(train_path)
        train_features_for_bank = preprocessor.transform_records(train_records_for_bank)
        latent_bank = build_latent_bank(model, train_features_for_bank, device=sample_device)
        with torch.no_grad():
            decoded = model.sample_from_latent_bank(
                latent_bank,
                int(sample_count),
                noise_scale=float(latent_noise_scale),
                device=sample_device,
            ).cpu().numpy()
    else:
        raise ValueError("sampling_method must be 'prior' or 'latent_bank'")

    payloads = [
        preprocessor.decode_profile_fields(
            decoded[idx],
            profile_id=f"VAE_AUDIT_{idx + 1:04d}",
            name=f"vae_audit_{idx + 1:04d}",
        )
        for idx in range(int(sample_count))
    ]
    manifest = dict(manifest)
    manifest["decoded_sample_method"] = str(sampling_method)
    manifest["decoded_latent_noise_scale"] = float(latent_noise_scale)
    return payloads, preprocessor, manifest


def audit_decoded_payloads(payloads: list[dict], *, convoy_profile: str) -> tuple[list, list[AttackProfile], list[dict], pd.DataFrame]:
    ships = get_convoy_layout_profile(convoy_profile).build_ships()
    profiles = [AttackProfile(**payload) for payload in payloads]
    audit_rows = audit_decoded_vae_payloads(
        payloads,
        ships,
        min_clearance_m=float(MIN_SPAWN_CLEARANCE_M_FOR_DECODED),
        rng_seed=int(AUDIT_SEED if "AUDIT_SEED" in globals() else SEED),
        outcome_cfg=OutcomeAuditConfig(t_max_s=float(DYNAMIC_AUDIT_T_MAX_S), hit_dt_s=float(DYNAMIC_AUDIT_DT_S)),
    )
    return ships, profiles, audit_rows, pd.DataFrame(audit_rows)

# %%
device_for_sampling = resolve_device(DEVICE)
AUDIT_PAYLOADS, AUDIT_PREPROCESSOR, AUDIT_MANIFEST = sample_profiles_from_checkpoint(
    RUN_DIR,
    checkpoint_name=AUDIT_CHECKPOINT_NAME,
    sample_count=int(SAMPLE_COUNT),
    device=device_for_sampling,
    sampling_method=str(VAE_SAMPLE_METHOD),
    train_path=PROJECT_ROOT / TRAIN_PATH,
    latent_noise_scale=float(LATENT_BANK_NOISE_SCALE),
    seed=int(SEED),
)
AUDIT_SHIPS, AUDIT_PROFILES, AUDIT_ROWS, audit_df = audit_decoded_payloads(
    AUDIT_PAYLOADS,
    convoy_profile=AUDIT_CONVOY_PROFILE,
)

audit_summary = summarize_decoded_vae_audit(audit_df.to_dict("records"))
audit_summary["sample_method"] = AUDIT_MANIFEST.get("decoded_sample_method", "prior")
audit_summary["latent_noise_scale"] = AUDIT_MANIFEST.get("decoded_latent_noise_scale", None)
audit_summary
# Out:
# {'samples': 1000,
#  'actual_outcome_labels': {'credible_hit_threat': 868,
#   'credible_near_miss': 82,
#   'miss': 50},
#  'centroid_static_labels': {'implausible_geometry': 670,
#   'credible_hit_threat': 330},
#  'clearance_ok_rate': 0.912,
#  'passes_safety_gate_rate': 0.912,
#  'min_clearance_m': 22.503977560742978,
#  'any_ship_hit_rate': 0.868,
#  'mean_hits': 2.561,
#  'mean_unique_ships_hit': 1.75,
#  'mean_closest_any_ship_distance_m': 97.76196633195366,
#  'sample_method': 'latent_bank',
#  'latent_noise_scale': 0.1}

# %%
train_records = load_dataset_records(PROJECT_ROOT / TRAIN_PATH)
train_rows = flatten_dataset_records(train_records[: int(TRAIN_COMPARE_LIMIT)])
train_df = pd.DataFrame(train_rows)
train_df["u_pos"] = train_df[["u_pos_x", "u_pos_y"]].values.tolist()

train_points = np.vstack(train_df["u_pos"].to_list()) if len(train_df) else None
vae_points = np.vstack(audit_df["u_pos"].to_list()) if len(audit_df) else None
extra_sets = [p for p in [train_points, vae_points] if p is not None]
shared_limits = combined_limits(AUDIT_SHIPS, extra_points=np.vstack(extra_sets) if extra_sets else None, pad=350.0)

fig, axes = plt.subplots(1, 2, figsize=(16, 7), facecolor="lightgrey")
style_ax(axes[0], "Training dataset spawns")
simple_ship_polygons(axes[0], AUDIT_SHIPS)
if len(train_df):
    train_xy = np.vstack(train_df["u_pos"].to_list())
    axes[0].scatter(train_xy[:, 0], train_xy[:, 1], c="#111111", s=10, alpha=0.18, zorder=2)
apply_limits(axes[0], shared_limits, fixed_x_limits=FIXED_X_LIMITS)
axes[0].set_xlabel("x (m)")
axes[0].set_ylabel("y (m)")

plot_spawn_comparison(
    axes[1],
    AUDIT_SHIPS,
    audit_df,
    title="VAE decoded spawns",
    accepted_only=False,
    limits=shared_limits,
)
apply_limits(axes[1], shared_limits, fixed_x_limits=FIXED_X_LIMITS)
plt.tight_layout()
plt.show()

# %%
feature_rows = []
for feature_name, mean, std in zip(
    AUDIT_PREPROCESSOR.feature_names,
    AUDIT_PREPROCESSOR.mean,
    AUDIT_PREPROCESSOR.std,
):
    feature_rows.append({"feature": feature_name, "mean": float(mean), "std": float(std)})
pd.DataFrame(feature_rows)
# Out:
#                     feature        mean          std
# 0                   u_pos_x  645.593628  2912.045410
# 1                   u_pos_y  -17.502625  5232.680176
# 2      sin_base_bearing_rad   -0.007251     0.777889
# 3      cos_base_bearing_rad   -0.072709     0.624135
# 4                spread_rad    0.077946     0.031519
# 5            launch_delay_s    1.502996     0.605597
# 6          salvo_interval_s    2.247111     0.559103
# 7  u_boat_initial_speed_mps    1.498151     0.316360

# %% [markdown]
# ## Follow-Up Notes
#
# After the first full v4 run, the main things to inspect are:
# - validation loss flattening versus overfitting
# - KL not collapsing to zero for the whole run
# - decoded spawn distribution compared with the training distribution
# - decoded clearance failures and static audit rejection rate
#
# If decoded samples are too diffuse, reduce `BETA` or `LATENT_DIM`. If recon quality is poor, increase `HIDDEN_DIM` or train longer.
