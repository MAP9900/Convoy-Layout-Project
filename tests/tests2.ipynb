# %%
#Imports
import sys, random
from pathlib import Path

# Walk up from the working directory until we find the project root
cwd = Path.cwd()
for candidate in (cwd,) + tuple(cwd.parents):
    if (candidate / "convoy_sim").is_dir():
        sys.path.append(str(candidate))
        break
else:
    raise RuntimeError("Unable to locate convoy_sim package root")

sys.executable
# Out:
# '/opt/homebrew/Caskroom/miniforge/base/envs/Python-DS/bin/python'

# %%
from scenarios.scenario_a import build_scenario_a

scenario = build_scenario_a(n_trials=100, rng_seed=1945)
result = scenario.run()
print(f"Scenario: {result['scenario']}")
print(f"Expected hits: {result['result']['expected_hits']:.2f}")
print(f"Hit prob ≥1: {result['result']['hit_prob_at_least_one']:.2f}")
result
# Out:
# Scenario: Scenario A
# Expected hits: 6.00
# Hit prob ≥1: 1.00
# {'scenario': 'Scenario A',
#  'result': {'hits_per_trial': array([6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6.,
#          6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6.,
#          6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6.,
#          6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6.,
#          6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6.,
#          6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6.]),
#   'expected_hits': 6.0,
#   'var_hits': 0.0,
#   'hit_prob_at_least_one': 1.0,
#   'n_trials': 100},
#  'metadata': {'description': 'Baseline rectangular convoy vs straight torpedo fan spread'}}

# %%
import pathlib, subprocess, sys

repo_root = pathlib.Path(".").resolve()
cmd = [
    sys.executable,
    str(repo_root / "experiments" / "run_scenario.py"),
    "scenario_a",
    "--trials",
    "200",
    "--seed",
    "1945",
    "--output",
    str(repo_root / "results"),]
print("Running:", " ".join(cmd))
subprocess.run(cmd, check=True)
# Out:
# Running: /opt/homebrew/Caskroom/miniforge/base/envs/Python-DS/bin/python /Users/matthewplambeck/Desktop/Convoy Layout Project/tests/experiments/run_scenario.py scenario_a --trials 200 --seed 1945 --output /Users/matthewplambeck/Desktop/Convoy Layout Project/tests/results
# /opt/homebrew/Caskroom/miniforge/base/envs/Python-DS/bin/python: can't open file '/Users/matthewplambeck/Desktop/Convoy Layout Project/tests/experiments/run_scenario.py': [Errno 2] No such file or directory
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[3], line 15
#       4 cmd = [
#       5     sys.executable,
#       6     str(repo_root / "experiments" / "run_scenario.py"),
#    (...)     12     "--output",
#      13     str(repo_root / "results"),]
#      14 print("Running:", " ".join(cmd))
# ---> 15 subprocess.run(cmd, check=True)
#
# ...
